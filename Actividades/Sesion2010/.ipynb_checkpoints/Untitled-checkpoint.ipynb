# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
fig =plt.figure(figsize=(12,4))
ax=fig.add_subplot(111)

ax.set_ylabel('Voltaje')
ax.set_title('Curva de PE')

t=np.arange(0.0,1.0,0.1)
s=np.sin(t)

# %%
fig=plt.figure(figsize=(12,4))
t=np.arange(0.0,1.0,0.05)
s=np.sin(2*np.pi*t)

ax1=fig.add_subplot(3,1,1)
ax1.set_ylabel('Voltaje')
ax1.set_title('Curva de PE')
line1=ax1.plot(t,s+5.0,color='red',lw=5)
line2=ax1.plot(t,s+3.0,color='blue',lw=3)
line3=ax1.plot(t,s,color='yellow',lw=1,)

ax2=fig.add_subplot(3,1,2)
ax2.set_ylabel('Voltaje')
ax2.set_title('Curva de PE')
line1=ax2.plot(t,s+5.0,color='red',lw=5,linestyle='--')
line2=ax2.plot(t,s+3.0,color='blue',lw=3,linestyle='-.')
line3=ax2.plot(t,s,color='yellow',lw=1,linestyle=':')

ax3=fig.add_subplot(3,1,3)
ax3.set_ylabel('Voltaje')
ax3.set_title('Curva de PE')
line1=ax3.plot(t,s+5.0,color='red',lw=5,marker='+')
line2=ax3.plot(t,s+3.0,color='#000000',lw=3,marker='o')
line3=ax3.plot(t,s,color='orange',lw=1,marker='^')

plt.subplots_adjust(wspace=0.5,hspace=0.5)

# %%
fig=plt.figure(figsize=(12,4))
ax=fig.add_subplot(111)

x1=np.random.normal(0,1,50)
x2=np.random.normal(1,2,50)
x3=np.random.normal(1,3,50)

p=ax.boxplot([x1,x2,x3])

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
x=np.random.normal(0,1,2000)
bins=50

graf=ax.hist(x,bins=bins,color='lightblue',alpha=0.6)

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
x=np.random.normal(0,1,2000)
bins=5

graf=ax.hist(x,bins=bins,color='lightblue',alpha=0.6)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig=plt.figure(figsize=(12,12))
ax=fig.add_subplot(111,projection='3d')
for c,z in zip(['red','green','blue','yellow'],[0,10,20,30]):
    xs=np.arange(20)
    ys=np.random.rand(20)
    
    cs=[c]*len(xs)
    cs[0]='orange'
    ax.bar(xs,ys,zs=z,zdir='y',color=cs,alpha=0.7)
    
    
a=ax.set_xlabel('X')
b=ax.set_ylabel('Y')
c=ax.set_zlabel('Z')

# %%
fig=plt.figure(figsize=(6,6))
with plt.style.context('dark_background'):
    N=4
    x=np.linspace(0,N)
    ncolors=len(mpl.rcParams['axes.prop_cylce'])
    shift=np.linspace(0,N,ncolors,endpoint=False)
    for g in shirt:
        plt.plot(x,np.sin(x+g),'--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8272\3161148050.py in <module>
#       3     N=4
#       4     x=np.linspace(0,N)
# ----> 5     ncolors=len(mpl.rcParams['axes.prop_cylce'])
#       6     shift=np.linspace(0,N,ncolors,endpoint=False)
#       7     for g in shirt:
#
# NameError: name 'mpl' is not defined
