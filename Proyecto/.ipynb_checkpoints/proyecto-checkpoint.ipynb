# %%
import pickle
# from functools import partial
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['figure.figsize'] = (9, 9)
import seaborn as sns
# import plotly.express as px

from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler, OneHotEncoder, RobustScaler
from sklearn.dummy import DummyClassifier
# feature selection
from sklearn.feature_selection import chi2, SelectPercentile, SelectKBest,f_regression,mutual_info_regression
# model selection
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sklearn.metrics import (r2_score, mean_squared_error, accuracy_score, precision_score, recall_score,
                             f1_score, roc_auc_score, roc_curve, precision_recall_curve, make_scorer,
                             confusion_matrix, multilabel_confusion_matrix, ConfusionMatrixDisplay)

# models
from statsmodels.tsa.arima.model import ARIMA
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, LogisticRegression, SGDRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor,ExtraTreesRegressor,ExtraTreesClassifier
from xgboost import XGBClassifier, XGBRegressor
import xgboost as xgb
from sklearn.decomposition import PCA,TruncatedSVD
# model explainability
import shap

# enable reload of changed files
# %reload_ext autoreload
# %autoreload 2

# plot inline
#%matplotlib inline

# make it pretty
#from rich.console import Console
#from rich import inspect
#con = Console()
#ins = partial(inspect, methods=True)
#%reload_ext rich
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import check_is_fitted
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, RobustScaler, OrdinalEncoder, FunctionTransformer
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
from sklearn.datasets import make_classification
#from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import (precision_recall_curve,PrecisionRecallDisplay)

def mod_eval(xtrain,xtest,ytrain,ytest,xfc,regressor,probs=0):
    kpi=pd.DataFrame(index=['mae','rmse','mape'])
    fc=pd.DataFrame(index=list(range(1,25)))
    
    regressor[1].fit(xtrain,ytrain)
    fctest=regressor[1].predict(xtest)
    mae = np.mean(abs(fctest - ytest.values))
    mape=(fctest - ytest.values)/ytest.values;
    mape=100*np.mean(abs(mape[np.isfinite(mape)]))
    rmse = np.sqrt(np.mean((fctest - ytest.values) ** 2))
    
    kpi.loc[:,regressor[0]]=[mae,rmse,mape]
    fc.loc[:,regressor[0]]=regressor[1].predict(xfc)
    
    if probs==1:
        p=prob_eval(regressor,xfc)
        fc=pd.concat([fc,p],axis=1)
    return kpi, fc

def prob_eval(regressor,xfc):
    fc=pd.DataFrame(index=list(range(1,25)))

# %%
# lectura de variables para pronostico de PML y OVEMEM
rawdata = pd.read_excel('data\input_vars.xlsx')
print(rawdata.dtypes,rawdata.isnull().sum())
# Out:
# Fecha      datetime64[ns]
# Mes                 int64
# Dia                 int64
# Diasem              int64
# Hora                int64
# Fest                int64
# MDA               float64
# MTR               float64
# Spread            float64
# Bin                 int64
# MW                float64
# SIN               float64
# FC                  int64
# MRO               float64
# TEM                 int64
# EO                float64
# FV                float64
# RES               float64
# MDA2              float64
# MDA3              float64
# MDA4              float64
# MW2               float64
# MW3               float64
# MW4               float64
# EO1               float64
# FV1               float64
# HSC1              float64
# SIN2              float64
# Spread4           float64
# FC1                 int64
# Bin3                int64
# Binh3               int64
# Bin7                int64
# Bin14               int64
# dtype: object Fecha      0
# Mes        0
# ...

# %%
df_datestr=rawdata[['Fecha','Hora']]
df_datetime=pd.DataFrame({'Fecha': rawdata.Fecha
                         +pd.to_timedelta(rawdata.Hora,unit='h')})

df_pml=rawdata.copy()
df_pml['Fecha']=df_datetime['Fecha'].dt.strftime('%d/%m/%Y %H')
df_pml.set_index('Fecha',inplace=True)

# %%
date_rng=['01/07/2022 01','01/01/2023 00']

# %%
#Selección de datos que se utilizan en entrenamiento y prueba de algoritmos
hist_data=df_pml['01/07/2022 01':'01/01/2023 00']

# Seleccion de datos que se utilizan en validación
val_data=df_pml['01/01/2023 01':]
val_data
# Out:
#                Mes  Dia  Diasem  Hora  Fest     MDA     MTR  Spread  Bin  \
# Fecha
# 01/01/2023 01    1    1       1     1     1  316.96  347.97   31.01    1
# 01/01/2023 02    1    1       1     2     1  122.18  329.72  207.54    1
# 01/01/2023 03    1    1       1     3     1  303.64  328.55   24.91    1
# 01/01/2023 04    1    1       1     4     1  111.55  292.46  180.91    1
# 01/01/2023 05    1    1       1     5     1   63.46  292.40  228.94    1
# ...            ...  ...     ...   ...   ...     ...     ...     ...  ...
# 14/01/2023 20    1   14       7    20     0  568.65    0.00 -568.65    0
# 14/01/2023 21    1   14       7    21     0  515.84    0.00 -515.84    0
# 14/01/2023 22    1   14       7    22     0  511.05    0.00 -511.05    0
# 14/01/2023 23    1   14       7    23     0  482.11    0.00 -482.11    0
# 15/01/2023 00    1   14       7    24     0  439.25    0.00 -439.25    0
#
#                     MW  ...       EO1    FV1   HSC1          SIN2  Spread4  \
# ...

# %%
pml_data=hist_data[['Diasem','MDA','MDA2','MDA3','MDA4','MW2','MW3','MW4','HSC1','TEM','EO1','FV1']]
#pml_data=hist_data[['MDA','MDA2','MDA3','MDA4','MW2','MW3','MW4','HSC1','TEM']]
pd.plotting.scatter_matrix(pml_data,alpha=0.4);

# %%
fig,ax=plt.subplots(figsize=(10, 8))
ax.set_title('Distribución de Features')

sns.kdeplot(pml_data['MDA'],ax=ax,label='MDA')
sns.kdeplot(pml_data['MDA2'],ax=ax,label='MDA2')
sns.kdeplot(pml_data['MDA3'],ax=ax,label='MDA3')
sns.kdeplot(pml_data['MDA4'],ax=ax,label='MDA4')
sns.kdeplot(pml_data['MW2'],ax=ax,label='MW2')
sns.kdeplot(pml_data['MW3'],ax=ax,label='MW3')
sns.kdeplot(pml_data['MW4'],ax=ax,label='MW4')
sns.kdeplot(pml_data['HSC1'],ax=ax,label='HSC1')
sns.kdeplot(pml_data['TEM'],ax=ax,label='TEM');
#sns.kdeplot(pml_data['EO1'],ax=ax,label='EO1')
#sns.kdeplot(pml_data['FV1'],ax=ax,label='FV1');
ax.legend();

# %%
X,y=pml_data.drop('MDA',axis=1),pml_data['MDA']
cols=X.columns.tolist()

# %%
# Input vars for LMP
# Selección de variable a pronosticar y datos de entrada a modelos
X_train,X_test,y_train,y_test=train_test_split(X,y,shuffle=False)
X_train
# Out:
#                Diasem     MDA2         MDA3     MDA4      MW2         MW3  \
# Fecha
# 01/07/2022 01       6  1128.67  1122.843333  1179.13  914.519  919.371542
# 01/07/2022 02       6  1128.05  1122.843333  1155.25  892.112  919.371542
# 01/07/2022 03       6  1081.02  1122.843333  1128.81  866.957  919.371542
# 01/07/2022 04       6  1075.36  1122.843333  1134.40  854.254  919.371542
# 01/07/2022 05       6  1067.40  1122.843333  1115.40  851.086  919.371542
# ...               ...      ...          ...      ...      ...         ...
# 15/11/2022 20       3   791.33   659.729583   585.38  824.931  771.822042
# 15/11/2022 21       3   776.50   659.729583   495.27  823.055  771.822042
# 15/11/2022 22       3   699.24   659.729583   487.37  807.959  771.822042
# 15/11/2022 23       3   681.40   659.729583   404.55  809.373  771.822042
# 16/11/2022 00       3   643.21   659.729583   364.10  798.595  771.822042
#
#                    MW4   HSC1  TEM       EO1    FV1
# Fecha
# ...

# %%
X_test
# Out:
#                Diasem    MDA2        MDA3    MDA4      MW2         MW3  \
# Fecha
# 16/11/2022 01       4  628.30  636.758750  487.26  732.567  742.256417
# 16/11/2022 02       4  621.73  636.758750  471.35  718.036  742.256417
# 16/11/2022 03       4  619.90  636.758750  470.39  699.941  742.256417
# 16/11/2022 04       4  616.26  636.758750  457.57  695.123  742.256417
# 16/11/2022 05       4  604.48  636.758750  461.82  696.738  742.256417
# ...               ...     ...         ...     ...      ...         ...
# 31/12/2022 20       7  592.72  482.617917  910.03  672.048  667.097250
# 31/12/2022 21       7  600.16  482.617917  887.30  668.302  667.097250
# 31/12/2022 22       7  567.55  482.617917  871.94  659.312  667.097250
# 31/12/2022 23       7  563.04  482.617917  846.68  657.788  667.097250
# 01/01/2023 00       7  663.49  482.617917  808.34  655.000  667.097250
#
#                    MW4   HSC1  TEM       EO1    FV1
# Fecha
# ...

# %%
# Create scaler object
ss = StandardScaler()
# Fit scaler to training data
ss.fit(X_train)

# Transform train and test X data and save as new variables
X_train_scaled = pd.DataFrame(ss.transform(X_train),columns=cols,index=X_train.index)
X_test_scaled = pd.DataFrame(ss.transform(X_test),columns=cols,index=X_test.index)

# %%
X_test_scaled
# Out:
#                  Diasem      MDA2      MDA3      MDA4       MW2       MW3  \
# Fecha
# 16/11/2022 01  0.003600 -1.488294 -1.518707 -2.042968 -0.360276 -0.294252
# 16/11/2022 02  0.003600 -1.506109 -1.518707 -2.088656 -0.498498 -0.294252
# 16/11/2022 03  0.003600 -1.511071 -1.518707 -2.091413 -0.670621 -0.294252
# 16/11/2022 04  0.003600 -1.520941 -1.518707 -2.128229 -0.716451 -0.294252
# 16/11/2022 05  0.003600 -1.552884 -1.518707 -2.116024 -0.701089 -0.294252
# ...                 ...       ...       ...       ...       ...       ...
# 31/12/2022 20  1.494189 -1.584772 -1.951889 -0.828896 -0.935945 -1.078897
# 31/12/2022 21  1.494189 -1.564598 -1.951889 -0.894170 -0.971578 -1.078897
# 31/12/2022 22  1.494189 -1.653022 -1.951889 -0.938279 -1.057093 -1.078897
# 31/12/2022 23  1.494189 -1.665252 -1.951889 -1.010819 -1.071589 -1.078897
# 01/01/2023 00  1.494189 -1.392873 -1.951889 -1.120920 -1.098109 -1.078897
#
#                     MW4      HSC1       TEM       EO1       FV1
# Fecha
# ...

# %%
fig,ax=plt.subplots(figsize=(10, 8))
ax.set_title('Distribución de Features')

sns.kdeplot(X_train_scaled['MDA2'],ax=ax,label='MDA2')
sns.kdeplot(X_train_scaled['MDA3'],ax=ax,label='MDA3')
sns.kdeplot(X_train_scaled['MDA4'],ax=ax,label='MDA4')
sns.kdeplot(X_train_scaled['MW2'],ax=ax,label='MW2')
sns.kdeplot(X_train_scaled['MW3'],ax=ax,label='MW3')
sns.kdeplot(X_train_scaled['MW4'],ax=ax,label='MW4')
sns.kdeplot(X_train_scaled['HSC1'],ax=ax,label='HSC1')
sns.kdeplot(X_train_scaled['TEM'],ax=ax,label='TEM')
sns.kdeplot(X_train_scaled['EO1'],ax=ax,label='EO1')
sns.kdeplot(X_train_scaled['FV1'],ax=ax,label='FV1');
ax.legend();

# %%
#fs=SelectKBest(score_func=f_regression,k='all')
#fs.fit(X_train_scaled,y_train)
#plt.barh(cols,fs.pvalues_);

# %%
X_sc_bf=pd.DataFrame(fs.transform(X_train_scaled),columns=cols,index=X_train_scaled.index)
X_sc_bf
# Out:
#                  Diasem      MDA2      MDA3      MDA4       MW2       MW3  \
# Fecha
# 01/07/2022 01  0.997326 -0.131501 -0.152663 -0.056120  1.370488  1.554788
# 01/07/2022 02  0.997326 -0.133182 -0.152663 -0.124696  1.157348  1.554788
# 01/07/2022 03  0.997326 -0.260708 -0.152663 -0.200624  0.918069  1.554788
# 01/07/2022 04  0.997326 -0.276055 -0.152663 -0.184571  0.797235  1.554788
# 01/07/2022 05  0.997326 -0.297640 -0.152663 -0.239134  0.767101  1.554788
# ...                 ...       ...       ...       ...       ...       ...
# 15/11/2022 20 -0.493262 -1.046225 -1.454152 -1.761196  0.518309  0.014406
# 15/11/2022 21 -0.493262 -1.086438 -1.454152 -2.019965  0.500464  0.014406
# 15/11/2022 22 -0.493262 -1.295935 -1.454152 -2.042652  0.356868  0.014406
# 15/11/2022 23 -0.493262 -1.344309 -1.454152 -2.280486  0.370318  0.014406
# 16/11/2022 00 -0.493262 -1.447864 -1.454152 -2.396647  0.267796  0.014406
#
#                     MW4      HSC1       TEM       EO1       FV1
# Fecha
# ...

# %%
fig,ax=plt.subplots(figsize=(10, 8))
ax.set_title('Distribución de Features')

sns.kdeplot(X_sc_bf['MDA2'],ax=ax,label='MDA2')
sns.kdeplot(X_sc_bf['MDA3'],ax=ax,label='MDA3')
sns.kdeplot(X_sc_bf['MDA4'],ax=ax,label='MDA4')
sns.kdeplot(X_sc_bf['MW2'],ax=ax,label='MW2')
sns.kdeplot(X_sc_bf['MW3'],ax=ax,label='MW3')
sns.kdeplot(X_sc_bf['MW4'],ax=ax,label='MW4')
sns.kdeplot(X_sc_bf['HSC1'],ax=ax,label='HSC1')
sns.kdeplot(X_sc_bf['TEM'],ax=ax,label='TEM')
sns.kdeplot(X_sc_bf['EO1'],ax=ax,label='EO1')
sns.kdeplot(X_sc_bf['FV1'],ax=ax,label='FV1');
ax.legend();

# %%
# LR on scaled data
reg = LinearRegression()
reg.fit(X_train_scaled, y_train)
reg.score(X_test_scaled, y_test)
# Out:
# 0.5069348212154123

# %%
# Ridge on original data
reg = Ridge()
reg.fit(X_train, y_train)
reg.score(X_test, y_test)
# Out:
# 0.5069108742065606

# %%
# Ridge on scaled data
reg = Ridge()
reg.fit(X_train_scaled, y_train)
reg.score(X_test_scaled, y_test)
# Out:
# 0.5068844681542948

# %%
# Pipeline
pipeline = Pipeline([
    ('ss', StandardScaler()),
    ('reg', Ridge())
])

pipeline.fit(X_train, y_train)
pipeline.score(X_test, y_test)
# Out:
# 0.5068844681542948

# %%
# GS on original data
params={
    'alpha': list(np.logspace(-2,4,num=100))
}

gs=GridSearchCV(Ridge(),params)

# %%
gs.fit(X_train_scaled,y_train)
gs.score(X_test_scaled,y_test)
# Out:
# 0.5037109304153213

# %%
# Lasso on original data
reg = Lasso()
reg.fit(X_train, y_train)
reg.score(X_test, y_test)
# Out:
# 0.5043360641912292

# %%
# Lasso on scaled data
reg = Lasso()
reg.fit(X_train_scaled, y_train)
reg.score(X_test_scaled, y_test)
# Out:
# 0.5064728544800009

# %%
# Pipeline
pipeline = Pipeline([
    ('ss', StandardScaler()),
    ('reg', Lasso())
])

pipeline.fit(X_train, y_train)
pipeline.score(X_test, y_test)
# Out:
# 0.5064728544800009

# %%
# GS on original data
params={
    'alpha': list(np.logspace(-2,4,num=100))
}

gs=GridSearchCV(Lasso(),params)

# %%
gs.fit(X_train_scaled,y_train)
gs.score(X_test_scaled,y_test)
# Out:
# 0.5059144167862107

# %%
gs.best_params_
# Out:
# {'alpha': 1.7475284000076847}

# %%
# Elastic on original data
reg = ElasticNet()
reg.fit(X_train, y_train)
reg.score(X_test, y_test)
# Out:
# 0.4800329150933609

# %%
# EN on scaled data
reg =ElasticNet()
reg.fit(X_train_scaled, y_train)
reg.score(X_test_scaled, y_test)
# Out:
# 0.3958872917307249

# %%
# Pipeline
pipeline = Pipeline([
    ('ss', StandardScaler()),
    ('reg',ElasticNet())
])

pipeline.fit(X_train, y_train)
pipeline.score(X_test, y_test)
# Out:
# 0.3958872917307249

# %%
# GS on original data
params={
    'alpha': list(np.logspace(-2,4,num=25)),
    'l1_ratio':list(np.linspace(0.01,0.99,25))
}

gs=GridSearchCV(ElasticNet(),params)

# %%
gs.fit(X_train_scaled,y_train)
gs.score(X_test_scaled,y_test)
# Out:
# 0.5026890263641105

# %%
gs.best_params_
# Out:
# {'alpha': 1.7782794100389228, 'l1_ratio': 0.99}

# %%
#RF on original data
reg = RandomForestRegressor(random_state=16)
reg.fit(X_train, y_train.values.ravel())
reg.score(X_test, y_test)
# Out:
# 0.4426651315668412

# %%
#RF on scaled data
reg = RandomForestRegressor(random_state=16)
reg.fit(X_train_scaled, y_train.values.ravel())
reg.score(X_test_scaled, y_test)
# Out:
# 0.4427962693289508

# %%
# Pipeline
pipeline = Pipeline([
    ('ss', StandardScaler()),
    ('reg',RandomForestRegressor(random_state=16))
])

pipeline.fit(X_train, y_train)
pipeline.score(X_test, y_test)
# Out:
# 0.4427962693289508

# %%
# GS on original data
params={
    'n_estimators': np.arange(100,1200,300),
    'max_depth': list(range(1,5))
}
gs=GridSearchCV(RandomForestRegressor(random_state=16),params)

# %%
gs.fit(X_train_scaled,y_train)
gs.score(X_test_scaled,y_test)
# Out:
# 0.4463553723953402

# %%
gs.best_params_
# Out:
# {'max_depth': 4, 'n_estimators': 400}

# %%
pipe_regs=Pipeline(steps=[
   # ('rge',Ridge()),
   # ('lso',Lasso()),
   # ('ent',ElasticNet()),
   # ('rfr',RandomForestRegressor()),
    ('etr',ExtraTreesRegressor())
])

# %%
params=[
#{
#    'models__rge__alpha': list(np.logspace(-2,4,num=100))
#},
#{
#    'models__lso__alpha': list(np.logspace(-2,4,num=100))
#},
#{
#    'models__ent__alpha': list(np.logspace(-2,4,num=25)),
#    'models__ent__l1_ratio': list(np.linspace(0.01,0.99,25))
#},
#{
#    'models__rfr__n_estimators': np.arange(100,1200,300),
#    'models__rfr__max_depth': list(range(1,6)),
#    'models__rfr__random_state':[16]
#},
{
    'models__etr__n_estimators': np.arange(100,1200,300),
    'models__etr__max_depth': list(range(1,6)),
    'models__etr__random_state':[16]
}]

# %%
print(pipe_regs)
# Out:
# Pipeline(steps=[('etr', ExtraTreesRegressor())])

# %%
pipe_pre=Pipeline(steps=[
    ('ss', StandardScaler())
])

# %%
pipe_gs=Pipeline(steps=[
    ('preprocessor',pipe_pre),
    ('models',pipe_regs)
])

# %%
pipe_gs
# Out:
# Pipeline(steps=[('preprocessor', Pipeline(steps=[('ss', StandardScaler())])),
#                 ('models', Pipeline(steps=[('etr', ExtraTreesRegressor())]))])

# %%
gs=GridSearchCV(pipe_gs,params)

# %%
gs.fit(X_train,y_train)
gs.score(X_test_scaled,y_test)
# Out:
# -6.33795471471381

# %%
reg = ExtraTreesRegressor(n_estimators=100)
# Fit logistic regression to scaled training data
reg.fit(X_train_scaled, y_train.values.ravel())
# Score logistic regression on scaled testing data
reg.score(X_test_scaled, y_test)

# %%
#label=df_pml['MDA']
#mod_vars=[['Hora','Dia','MDA2','MDA3','MDA4','MW2','MW3','MW4'],
#          ['Hora','Dia','MDA2','MDA3','MDA4','MW2','MW3','MW4','HSC1','TEM'],
#          ['Hora','Dia','MDA2','MDA3','MDA4','MW2','MW3','MW4','EO1','FV1']]

# Modelos considerados y variables de salida:
# pml_fc -> Pronostico de PML
# pml_ind -> Indicadores del modelo durante prueba
model_name_list = ['LR','RF', 'ET','RF+GT','RF+EF']
pml_fc=pd.DataFrame(index=list(range(1,25)))
pml_ind=pd.DataFrame(index=['mae','rmse','mape'])

# Regresores utilizados benchmark
lr=['LR',LinearRegression()]
et=['ET',ExtraTreesRegressor(n_estimators=50)]
rf=['RFx',RandomForestRegressor(n_estimators=50)]
log=['LOG',LogisticRegression(solver='liblinear')]
etx=['ET',ExtraTreesClassifier(n_estimators=1000,random_state=42)]
rfx=['RF',RandomForestClassifier(n_estimators=1000,random_state=42)]
log_pml=['LOG+',LogisticRegression(solver='liblinear')]

# Regresores utilizados Grid Search/Cross Validation
lr-gs=['LR',LinearRegression()]
et-gs=['ET',ExtraTreesRegressor()]
rf-gs=['RFx',RandomForestRegressor()]
log-gs=['LOG',LogisticRegression()]
etx-gs=['ET',ExtraTreesClassifier()]
rfx-gs=['RF',RandomForestClassifier()]
log_pml-gs=['LOG+',LogisticRegression()]

# %%
# En todos los modelos se segmentan las series de tiempo para entrenamiento y prueba. 
# La funcion mod_eval realiza el entrenamiento, prueba y pronóstico de MDA 
# Los resultados se almacenan en pml_fc y pml_ind 

# LR
X=df_pml[mod_vars[0]]
X_fc=df_fc[mod_vars[0]]
X_train, X_test, y_train, y_test = train_test_split(X, label, test_size = 0.25,random_state=42)
metrics,forecast=mod_eval(X_train,X_test,y_train,y_test,X_fc,lr)
pml_fc=pd.concat([pml_fc,forecast],axis=1)
pml_ind=pd.concat([pml_ind,metrics],axis=1)

# %%
data1=data.drop(columns=['instant','dteday','yr'],axis=1)
data1

# %%
from sklearn.model_selection import train_test_split

# %%
X=data1.drop('rentals',axis=1)
y=data1['rentals']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)
X_test

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OrdinalEncoder,MinMaxScaler
from sklearn.compose import ColumnTransformer

# %%
numeric_transformer=Pipeline(steps=[
    ('scalar',StandardScaler())
])

#categorical_transformer=Pipeline(steps=[
#    ('imputer',SimpleImputer(strategy='constant')),
#    ('encoder',OrdinalEncoder)
#])

# %%
numeric_f=['temp','atemp','hum','windspeed']
categorical_f=['season','mnth','holiday','weekday','workingday','weathersit']

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ('numeric',numeric_transformer,numeric_f),
        ('categorical',categorical_transformer,categorical_f)
    ]
)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
pipeline_m=Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('regressor',RandomForestRegressor())
])
pipeline_m

# %%
Model=pipeline_m.fit(X_train,y_train)
print(Model)
